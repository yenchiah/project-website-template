# %%
import geopandas as gpd
import folium
from folium.plugins import MarkerCluster
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
bus_routes_gdf = gpd.read_file('/content/drive/MyDrive/KingCountyTransit/KingCountyTransitData/KingCountyTransitRoutes.geojson')
bus_stops_gdf = gpd.read_file('/content/drive/MyDrive/KingCountyTransit/KingCountyTransitData/KingCountyTransitStops.geojson')
zip_codes_gdf = gpd.read_file('/content/drive/MyDrive/KingCountyTransit/KingCountyTransitData/KingCountyZipCodes.geojson')

# %%
#These datasets may be using different coordinate systems
print(bus_routes_gdf.crs)
print(bus_stops_gdf.crs)
print(zip_codes_gdf.crs)
# Out:
# EPSG:4326
# EPSG:4326
# EPSG:4326

# %%
print(bus_routes_gdf.info())
print(bus_stops_gdf.info())
print(zip_codes_gdf.info())
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ROUTE_ID            148 non-null    int64
#  1   LOCAL_EXPRESS_CODE  148 non-null    object
#  2   ROUTE_NUM           148 non-null    int64
#  3   SHAPE_Length        148 non-null    float64
#  4   geometry            148 non-null    geometry
# dtypes: float64(1), geometry(1), int64(2), object(1)
# memory usage: 5.9+ KB
# None
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 23369 entries, 0 to 23368
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   OBJECTID                   23369 non-null  int64
#  1   STOP_ID                    23369 non-null  int64
#  2   TRANS_LINK_ID              23369 non-null  int64
#  3   STOP_TYPE                  23369 non-null  object
#  4   TRF_DISTRICT_CODE          23369 non-null  object
#  5   BIKE_RACK                  23369 non-null  object
#  6   CURRENT_NEXT_CODE          23369 non-null  object
#  7   CF_CROSS_STREETNAME        23369 non-null  object
#  8   CF_DIST_FROM_INTERSECTION  23369 non-null  float64
#  9   CF_INTERSECTION_LOCCODE    23369 non-null  object
#  10  DATE_CREATED               23369 non-null  datetime64[ns, UTC]
#  11  DATE_LAST_MODIFIED         23369 non-null  datetime64[ns, UTC]
#  12  DISPLACEMENT               23369 non-null  float64
#  13  DIST_FROM_INTERSECTION     23369 non-null  float64
#  14  EFFECTIVE_BEGINDATE        23369 non-null  datetime64[ns, UTC]
#  15  FARE_ZONE                  23369 non-null  int64
#  16  HASTUS_CROSS_STREET_NAME   23369 non-null  object
#  17  INFOSIGN                   23369 non-null  object
#  18  INTERSECTION_LOC           23369 non-null  object
#  19  JURISDICTION               23369 non-null  object
#  20  KCM_MANAGED_EQUIPMENT      23369 non-null  object
#  21  XCOORD                     23369 non-null  float64
#  22  XCOORD_OFFSET              23369 non-null  int64
#  23  YCOORD                     23369 non-null  float64
#  24  YCOORD_OFFSET              23369 non-null  float64
#  25  ZIPCODE                    23369 non-null  object
#  26  ROUTE_LIST                 20536 non-null  object
#  27  ON_STREET_NAME             23369 non-null  object
#  28  ROUTESIGN                  23369 non-null  object
#  29  ROUTESIGN_OWNER            23369 non-null  object
#  30  NUM_SHELTERS               23369 non-null  int64
#  31  GISOBJID                   23369 non-null  float64
#  32  geometry                   23369 non-null  geometry
#  33  STOPS_IN_ZIPCODE           23369 non-null  int64
#  34  AREA_SQMI                  23369 non-null  float64
# dtypes: datetime64[ns, UTC](3), float64(8), geometry(1), int64(7), object(16)
# memory usage: 6.4+ MB
# None
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ZIPCODE       209 non-null    object
#  1   COUNTY        209 non-null    object
#  2   ZIP_TYPE      209 non-null    object
#  3   COUNTY_NAME   209 non-null    object
#  4   CITY_NAME     209 non-null    object
#  5   Shape_Length  209 non-null    float64
#  6   Shape_Area    209 non-null    float64
#  7   geometry      209 non-null    geometry
# dtypes: float64(2), geometry(1), object(5)
# memory usage: 13.2+ KB
# None

# %% [markdown]
# Let's clean up the bus_routes geodataframe.

# %%
bus_stops_gdf.head()

# %%
bus_stops_gdf['STOP_STATUS'].unique()
# Out:
# array(['ACT', 'CLO', 'INA', 'PLN'], dtype=object)

# %%
#remove all entries from bus_stops_gdf where 'STOP_STATUS'   is not 'ACT'

bus_stops_gdf = bus_stops_gdf[bus_stops_gdf['STOP_STATUS'] == 'ACT']

# %%
# Dropping columns from bus_stops_gdf
columns_to_drop = ['CHANGE_NUM','MINOR_CHANGE_NUM','AUTH_CODE','AUTH_NAME','ACCESSIBILITY_DECAL','ACCESSIBILITY_DECAL','ACCESSORY_SIGN','STOP_STATUS','AWNING','BAY_CODE','BEARING_CODE',
                   'CURB','CURB_HEIGHT_FRONTDOOR','CURBPAINT','CURBPAINTLENGTH','DB_MOD_DATE','FRDOORLANDING','FRDOORSIDEWALKWIDTH',
                   'IMT_CONNECTORLIST','IN_SERVICE_FLAG','INFOSIGN_ANCHOR','SIGN_MOUNTING_DIR','SIGNPOST','SIGNPOST_ANCHOR','SCHEDULE_HOLDER']
bus_stops_gdf = bus_stops_gdf.drop(columns=columns_to_drop)

bus_stops_gdf.head()
# Out:
#    OBJECTID  STOP_ID  TRANS_LINK_ID STOP_TYPE TRF_DISTRICT_CODE BIKE_RACK  \
# 0         1    99596         384121       REG                NW        NO
# 1         2    99597         384119       REG                NE        NO
# 2         3    99598         384121       REG                NE        NO
# 3         4    99599         381099       LAY                NE        NO
# 4         5    99600         381084        RL                NE        NO
#
#   CURRENT_NEXT_CODE CF_CROSS_STREETNAME  CF_DIST_FROM_INTERSECTION  \
# 0           CURRENT          N 148th St                      100.0
# 1           CURRENT         NE 130th St                      100.0
# 2           CURRENT         NE 130th St                      100.0
# 3           CURRENT       ST Light Rail                       33.0
# 4           CURRENT     Pedestrian Walk                      128.0
#
#   CF_INTERSECTION_LOCCODE  ...    YCOORD YCOORD_OFFSET  ZIPCODE  ROUTE_LIST  \
# 0                      AT  ...  271625.6      271634.0    98155        None
# 1                      AT  ...  267463.4      267464.7    98125        None
# 2                      AT  ...  267462.6      267461.3    98125        None
# 3                      FS  ...  260538.8      260538.5    98125        None
# 4                      NM  ...  260009.7      260009.4    98125         599
#
#        ON_STREET_NAME  ROUTESIGN ROUTESIGN_OWNER NUM_SHELTERS     GISOBJID  \
# 0       ST Light Rail    Unknown             UNK            0  100016297.0
# 1       ST Light Rail    Unknown             UNK            0  100016296.0
# 2       ST Light Rail    Unknown             UNK            0  100016295.0
# 3       ST Light Rail    Unknown             UNK            0  100016127.0
# 4  Northgate Sta Rail    Unknown              ST            0  100016114.0
#
#                       geometry
# 0  POINT (-122.32435 47.73493)
# 1  POINT (-122.32399 47.72350)
# 2  POINT (-122.32373 47.72350)
# 3  POINT (-122.32821 47.70446)
# 4  POINT (-122.32812 47.70301)
#
# [5 rows x 33 columns]

# %%
# I want to create columns for the total number of bus stops in the zipcode

stops_count_per_zipcode = bus_stops_gdf.groupby('ZIPCODE').size().reset_index(name='STOPS_IN_ZIPCODE')
# Merge the count back onto the original GeoDataFrame
bus_stops_gdf = bus_stops_gdf.merge(stops_count_per_zipcode, on='ZIPCODE', how='left')

# %% [markdown]
# Now we'll clean up the bus_routes geodataframe

# %%
bus_routes_gdf.head()

# %%
# All the bus routes are in service, so we'll drop some of its columns.

columns_to_drop = ['OBJECTID','CHANGE_NUM','MINOR_CHANGE_NUM','CURRENT_NEXT_CODE','IN_SERVICE_FLAG']
bus_routes_gdf = bus_routes_gdf.drop(columns=columns_to_drop)

bus_routes_gdf.head()
# Out:
#    ROUTE_ID LOCAL_EXPRESS_CODE  ROUTE_NUM   SHAPE_Length  \
# 0    100001                  L          1   41571.633227
# 1    100002                  L         10   22811.506576
# 2    100003                  L        101  128228.499464
# 3    100048                  L        153   73375.101802
# 4    100060                  L        168   86790.958365
#
#                                             geometry
# 0  MULTILINESTRING ((-122.31775 47.59920, -122.31...
# 1  MULTILINESTRING ((-122.32680 47.61522, -122.32...
# 2  MULTILINESTRING ((-122.21243 47.47169, -122.21...
# 3  MULTILINESTRING ((-122.23280 47.38482, -122.23...
# 4  MULTILINESTRING ((-122.03780 47.35797, -122.04...

# %%
bus_routes_gdf.head()

# %% [markdown]
# I want to calculate the area of each zip code. Given that zip_codes_gdf is in the EPSG:4326 coordinate system in latitude and longitude, which does not preserve distances or areas. I'll project it into UTM zone 10N.

# %%
# Project to UTM zone 10N for this area
zip_codes_gdf_projected = zip_codes_gdf.to_crs(epsg=32610)

# %%
# Calculate area in square meters
zip_codes_gdf_projected['AREA_SQM'] = zip_codes_gdf_projected.area

# %%
# Ensure ZIPCODE is a string and this dataframe is independent
zip_area = zip_codes_gdf_projected[['ZIPCODE', 'AREA_SQM']].copy()
zip_area['ZIPCODE'] = zip_area['ZIPCODE'].astype(str)

# %%
# Ensure the ZIPCODE in bus_stops is a string
bus_stops_gdf['ZIPCODE'] = bus_stops_gdf['ZIPCODE'].astype(str)

# Merge
bus_stops_gdf = bus_stops_gdf.merge(zip_area, on='ZIPCODE', how='left')

# %%
bus_stops_gdf.head()
# Out:
#    OBJECTID  STOP_ID  TRANS_LINK_ID STOP_TYPE TRF_DISTRICT_CODE BIKE_RACK  \
# 0         1    99596         384121       REG                NW        NO
# 1         2    99597         384119       REG                NE        NO
# 2         3    99598         384121       REG                NE        NO
# 3         4    99599         381099       LAY                NE        NO
# 4         5    99600         381084        RL                NE        NO
#
#   CURRENT_NEXT_CODE CF_CROSS_STREETNAME  CF_DIST_FROM_INTERSECTION  \
# 0           CURRENT          N 148th St                      100.0
# 1           CURRENT         NE 130th St                      100.0
# 2           CURRENT         NE 130th St                      100.0
# 3           CURRENT       ST Light Rail                       33.0
# 4           CURRENT     Pedestrian Walk                      128.0
#
#   CF_INTERSECTION_LOCCODE  ... ZIPCODE ROUTE_LIST      ON_STREET_NAME  \
# 0                      AT  ...   98155       None       ST Light Rail
# 1                      AT  ...   98125       None       ST Light Rail
# 2                      AT  ...   98125       None       ST Light Rail
# 3                      FS  ...   98125       None       ST Light Rail
# 4                      NM  ...   98125        599  Northgate Sta Rail
#
#    ROUTESIGN ROUTESIGN_OWNER  NUM_SHELTERS     GISOBJID  \
# 0    Unknown             UNK             0  100016297.0
# 1    Unknown             UNK             0  100016296.0
# 2    Unknown             UNK             0  100016295.0
# 3    Unknown             UNK             0  100016127.0
# 4    Unknown              ST             0  100016114.0
#
#                       geometry STOPS_IN_ZIPCODE      AREA_SQM
# 0  POINT (-122.32435 47.73493)              372  2.146118e+07
# 1  POINT (-122.32399 47.72350)              499  1.671915e+07
# 2  POINT (-122.32373 47.72350)              499  1.671915e+07
# 3  POINT (-122.32821 47.70446)              499  1.671915e+07
# 4  POINT (-122.32812 47.70301)              499  1.671915e+07
#
# [5 rows x 35 columns]

# %%
# Now, calculate stops per square meter for each ZIP code
bus_stops_gdf['STOPS_PER_SQM'] = bus_stops_gdf['STOPS_IN_ZIPCODE'] / bus_stops_gdf['AREA_SQM']

# %%
# Save bus_stops_gdf to a GeoJSON file
bus_stops_gdf.to_file("bus_stops.geojson", driver='GeoJSON')

# Save bus_routes_gdf to a GeoJSON file
bus_routes_gdf.to_file("bus_routes.geojson", driver='GeoJSON')

# %%
# Define the file paths
bus_stops_path = '/content/drive/My Drive/KingCountyTransit/KingCountyTransitData/bus_stops.geojson'
bus_routes_path = '/content/drive/My Drive/KingCountyTransit/KingCountyTransitData/bus_routes.geojson'

# Save the GeoDataFrames
bus_stops_gdf.to_file(bus_stops_path, driver='GeoJSON')
bus_routes_gdf.to_file(bus_routes_path, driver='GeoJSON')
