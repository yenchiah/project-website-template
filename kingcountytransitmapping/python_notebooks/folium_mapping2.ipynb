# %% [markdown]
# ### Mapping King County Bus Routes, Stops, and Stop Density by Zip Code

# %%
import geopandas as gpd
import folium
from folium import plugins
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
bus_routes_gdf = gpd.read_file('/content/drive/MyDrive/KingCountyTransit/Data/bus_routes.geojson')
bus_stops_gdf = gpd.read_file('/content/drive/MyDrive/KingCountyTransit/Data/bus_stops.geojson')
zip_codes_gdf = gpd.read_file('/content/drive/MyDrive/KingCountyTransit/Data/zip_codes.geojson')

# %%
bus_stops_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 22228 entries, 0 to 22227
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   STOP_ID                    22228 non-null  object
#  1   TRANS_LINK_ID              22228 non-null  object
#  2   STOP_TYPE                  22228 non-null  object
#  3   TRF_DISTRICT_CODE          22228 non-null  object
#  4   BEARING_CODE               22228 non-null  object
#  5   CF_CROSS_STREETNAME        22228 non-null  object
#  6   CF_DIST_FROM_INTERSECTION  22228 non-null  float64
#  7   CF_INTERSECTION_LOCCODE    22228 non-null  object
#  8   DISPLACEMENT               22228 non-null  float64
#  9   DIST_FROM_INTERSECTION     22228 non-null  float64
#  10  FARE_ZONE                  22228 non-null  object
#  11  HASTUS_CROSS_STREET_NAME   22228 non-null  object
#  12  INFOSIGN                   22228 non-null  object
#  13  INTERSECTION_LOC           22228 non-null  object
#  14  JURISDICTION               22228 non-null  object
#  15  XCOORD                     22228 non-null  float64
#  16  XCOORD_OFFSET              22228 non-null  int64
#  17  YCOORD                     22228 non-null  float64
#  18  YCOORD_OFFSET              22228 non-null  float64
#  19  ZIPCODE                    22228 non-null  object
#  20  ROUTE_LIST                 19648 non-null  object
#  21  ON_STREET_NAME             22228 non-null  object
#  22  BUS_STOP_GISOBJID          22228 non-null  object
#  23  STOPS_IN_ZIPCODE           22228 non-null  int64
#  24  ZIPCODE_AREA_SQM           22228 non-null  float64
#  25  ZIPCODE_STOPS_PER_SQM      22228 non-null  float64
#  26  geometry                   22228 non-null  geometry
# dtypes: float64(8), geometry(1), int64(2), object(16)
# memory usage: 4.6+ MB

# %%
bus_routes_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ROUTE_ID            148 non-null    object
#  1   LOCAL_EXPRESS_CODE  148 non-null    object
#  2   ROUTE_NUM           148 non-null    object
#  3   SHAPE_Length        148 non-null    float64
#  4   geometry            148 non-null    geometry
# dtypes: float64(1), geometry(1), object(3)
# memory usage: 5.9+ KB

# %%
zip_codes_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ZIPCODE            209 non-null    object
#  1   COUNTY             209 non-null    object
#  2   ZIP_TYPE           209 non-null    object
#  3   COUNTY_NAME        209 non-null    object
#  4   CITY_NAME          209 non-null    object
#  5   Shape_Length       209 non-null    float64
#  6   Shape_Area         209 non-null    float64
#  7   ZIPCODE_AREA_SQM   209 non-null    float64
#  8   TOTAL_BUS_STOPS    209 non-null    int64
#  9   BUS_STOPS_PER_SQM  209 non-null    float64
#  10  geometry           209 non-null    geometry
# dtypes: float64(4), geometry(1), int64(1), object(5)
# memory usage: 18.1+ KB

# %%
import folium

def create_kc_map(map_name='base_map', location=[47.608013, -122.335167],
                    zoom_start=12, max_zoom=25,
                    tiles='https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
                    attr='Esri', overlay=False, control=True):

    m = folium.Map(location=location, zoom_start=zoom_start, max_zoom=max_zoom, control_scale=True)
    base_layer = folium.TileLayer(tiles=tiles, attr=attr, name=map_name, overlay=overlay, control=control)
    base_layer.add_to(m)
    return m

# %%
m1 = create_kc_map()

# %% [markdown]
# Now, we'll add some layers to the map for King County Transit. There is a lot of information, so it would be best if certain features can be toggled on and off.

# %%
# Let's visualize the two bus route types independently

express_routes_gdf = bus_routes_gdf[bus_routes_gdf['LOCAL_EXPRESS_CODE'] == 'E']
local_routes_gdf = bus_routes_gdf[bus_routes_gdf['LOCAL_EXPRESS_CODE'] == 'L']

# %%
def add_express_routes(m):
    folium.GeoJson(
        express_routes_gdf,
        name='Express Routes',
        style_function=lambda x: {'color': '#32CD32', 'weight': 3, 'opacity': 0.7}
    ).add_to(m)

def add_local_routes(m):
    folium.GeoJson(
        local_routes_gdf,
        name='Local Routes',
        style_function=lambda x: {'color': 'darkred', 'weight': 2, 'opacity': 0.7}
    ).add_to(m)

# %%
add_express_routes(m1)
add_local_routes(m1)

# %%
# Add legend for route types

def add_route_legend(map_object):
  legend_html = '''
  <div style="position: fixed;
      bottom: 50px; left: 50px; width: 150px; height: 80px;
      border:2px solid grey; z-index:9999; font-size:14px;
      ">&nbsp; <b>Route Type:</b><br>
      &nbsp; Express &nbsp; <i style="background:brightgreen; width:20px; height:10px; display:inline-block;"></i><br>
      &nbsp; Local &nbsp; <i style="background:darkred; width:20px; height:10px; display:inline-block;"></i>
  </div>
  '''

  legend = folium.Html(legend_html, script=True)
  folium.Element(legend.render()).add_to(map_object)

# %%
add_route_legend(m1)

# %%
#m1
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Now we'll add bus stop information.

# %%
from folium.plugins import MarkerCluster

def mark_bus_stops(map_object, bus_stops_gdf):
  for _, row in bus_stops_gdf.iterrows():
    folium.Marker(
        location=[row['YCOORD'], row['XCOORD']],
        icon=folium.Icon(icon='bus', prefix='fa', color='orange')
    ).add_to(map_object)

# %%
from folium.plugins import HeatMap

def create_heatmap_bus_stops(map_object, bus_stops_gdf):
  heatmap_data = bus_stops_gdf[['YCOORD', 'XCOORD']].values.tolist()
  HeatMap(heatmap_data).add_to(map_object)

# %%
mark_bus_stops(m1, bus_stops_gdf)

create_heatmap_bus_stops(m1, bus_stops_gdf)

# %%
#m1
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
pip install mapbox-tilesets
# Out:
# Collecting mapbox-tilesets
#   Downloading mapbox_tilesets-1.9.3-py3-none-any.whl (16 kB)
# Collecting boto3 (from mapbox-tilesets)
#   Downloading boto3-1.34.49-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 3.5 MB/s eta 0:00:00
# Collecting click~=8.0.2 (from mapbox-tilesets)
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: cligj in /usr/local/lib/python3.10/dist-packages (from mapbox-tilesets) (0.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mapbox-tilesets) (1.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from mapbox-tilesets) (2.31.0)
# Collecting requests-toolbelt (from mapbox-tilesets)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.4 MB/s eta 0:00:00
# Collecting jsonschema~=3.0 (from mapbox-tilesets)
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 6.4 MB/s eta 0:00:00
# Collecting jsonseq~=1.0 (from mapbox-tilesets)
#   Downloading jsonseq-1.0.0-py3-none-any.whl (4.6 kB)
# Collecting mercantile~=1.1.6 (from mapbox-tilesets)
#   Downloading mercantile-1.1.6-py3-none-any.whl (13 kB)
# Collecting geojson~=2.5.0 (from mapbox-tilesets)
#   Downloading geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema~=3.0->mapbox-tilesets) (23.2.0)
# Collecting pyrsistent>=0.14.0 (from jsonschema~=3.0->mapbox-tilesets)
#   Downloading pyrsistent-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from jsonschema~=3.0->mapbox-tilesets) (67.7.2)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema~=3.0->mapbox-tilesets) (1.16.0)
# Collecting botocore<1.35.0,>=1.34.49 (from boto3->mapbox-tilesets)
#   Downloading botocore-1.34.49-py3-none-any.whl (12.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 21.9 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->mapbox-tilesets)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3->mapbox-tilesets)
#   Downloading s3transfer-0.10.0-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 12.6 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->mapbox-tilesets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->mapbox-tilesets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->mapbox-tilesets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->mapbox-tilesets) (2024.2.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.35.0,>=1.34.49->boto3->mapbox-tilesets) (2.8.2)
# Installing collected packages: jsonseq, geojson, pyrsistent, jmespath, click, requests-toolbelt, mercantile, jsonschema, botocore, s3transfer, boto3, mapbox-tilesets
#   Attempting uninstall: click
#     Found existing installation: click 8.1.7
#     Uninstalling click-8.1.7:
#       Successfully uninstalled click-8.1.7
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.19.2
#     Uninstalling jsonschema-4.19.2:
#       Successfully uninstalled jsonschema-4.19.2
# Successfully installed boto3-1.34.49 botocore-1.34.49 click-8.0.4 geojson-2.5.0 jmespath-1.0.1 jsonschema-3.2.0 jsonseq-1.0.0 mapbox-tilesets-1.9.3 mercantile-1.1.6 pyrsistent-0.20.0 requests-toolbelt-1.0.0 s3transfer-0.10.0

# %%
pip install mapbox-tilesets[estimate-area]
# Out:
# Requirement already satisfied: mapbox-tilesets[estimate-area] in /usr/local/lib/python3.10/dist-packages (1.9.3)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.10/dist-packages (from mapbox-tilesets[estimate-area]) (1.34.49)
# Requirement already satisfied: click~=8.0.2 in /usr/local/lib/python3.10/dist-packages (from mapbox-tilesets[estimate-area]) (8.0.4)
# Requirement already satisfied: cligj in /usr/local/lib/python3.10/dist-packages (from mapbox-tilesets[estimate-area]) (0.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mapbox-tilesets[estimate-area]) (1.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from mapbox-tilesets[estimate-area]) (2.31.0)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.10/dist-packages (from mapbox-tilesets[estimate-area]) (1.0.0)
# Requirement already satisfied: jsonschema~=3.0 in /usr/local/lib/python3.10/dist-packages (from mapbox-tilesets[estimate-area]) (3.2.0)
# Requirement already satisfied: jsonseq~=1.0 in /usr/local/lib/python3.10/dist-packages (from mapbox-tilesets[estimate-area]) (1.0.0)
# Requirement already satisfied: mercantile~=1.1.6 in /usr/local/lib/python3.10/dist-packages (from mapbox-tilesets[estimate-area]) (1.1.6)
# Requirement already satisfied: geojson~=2.5.0 in /usr/local/lib/python3.10/dist-packages (from mapbox-tilesets[estimate-area]) (2.5.0)
# Collecting supermercado~=0.2.0 (from mapbox-tilesets[estimate-area])
#   Downloading supermercado-0.2.0-py3-none-any.whl (8.1 kB)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema~=3.0->mapbox-tilesets[estimate-area]) (23.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema~=3.0->mapbox-tilesets[estimate-area]) (0.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from jsonschema~=3.0->mapbox-tilesets[estimate-area]) (67.7.2)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema~=3.0->mapbox-tilesets[estimate-area]) (1.16.0)
# Collecting affine (from supermercado~=0.2.0->mapbox-tilesets[estimate-area])
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from supermercado~=0.2.0->mapbox-tilesets[estimate-area]) (1.1.1)
# Collecting rasterio (from supermercado~=0.2.0->mapbox-tilesets[estimate-area])
#   Downloading rasterio-1.3.9-cp310-cp310-manylinux2014_x86_64.whl (20.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 58.8 MB/s eta 0:00:00
# Requirement already satisfied: botocore<1.35.0,>=1.34.49 in /usr/local/lib/python3.10/dist-packages (from boto3->mapbox-tilesets[estimate-area]) (1.34.49)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3->mapbox-tilesets[estimate-area]) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from boto3->mapbox-tilesets[estimate-area]) (0.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->mapbox-tilesets[estimate-area]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->mapbox-tilesets[estimate-area]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->mapbox-tilesets[estimate-area]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->mapbox-tilesets[estimate-area]) (2024.2.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.35.0,>=1.34.49->boto3->mapbox-tilesets[estimate-area]) (2.8.2)
# Collecting snuggs>=1.4.1 (from rasterio->supermercado~=0.2.0->mapbox-tilesets[estimate-area])
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.10/dist-packages (from snuggs>=1.4.1->rasterio->supermercado~=0.2.0->mapbox-tilesets[estimate-area]) (3.1.1)
# Installing collected packages: snuggs, affine, rasterio, supermercado
# Successfully installed affine-2.4.0 rasterio-1.3.9 snuggs-1.4.7 supermercado-0.2.0

# %% [markdown]
# Let's add ZIPCODE information.

# %%
import folium

def display_zipcode_overlay(map_object, zip_codes_gdf, attribute='TOTAL_BUS_STOPS'):

    # Create a tooltip that dynamically fetches the ZIPCODE and the specified attribute
    folium.GeoJson(
        zip_codes_gdf,
        style_function=lambda x: {'color': 'blue', 'weight': 2, 'opacity': 0.5},
        tooltip=folium.GeoJsonTooltip(fields=['ZIPCODE', attribute],
                                      aliases=['ZIP Code:', f'{attribute}:'],
                                      localize=True)
    ).add_to(map_object)

# %%
display_zipcode_overlay(m1, zip_codes_gdf)

# %%
folium.LayerControl().add_to(m1)

# %%
m1
# Out:
# Output hidden; open in https://colab.research.google.com to view.
